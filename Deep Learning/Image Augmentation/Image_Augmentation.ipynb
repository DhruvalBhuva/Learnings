# %%
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
img = image.load_img("./cat.jpg", target_size=(200, 200))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    # There are diffrent fill mode, it defines how empty pixel to be filled while shifting the object
    fill_mode='nearest'
)

# %%
# Here image is not an numpy array
print(type(img))

# Converting image to numpy array
img = image.img_to_array(img)
img.shape
# Out:
# <class 'PIL.Image.Image'>
# (200, 200, 3)

# %%
# We gives images to model in the batches, so reshapig it
input_batch = img.reshape((1,) + img.shape)
input_batch.shape
# Out:
# (1, 200, 200, 3)

# %%
# flow: We use flow when we are working with a single numpy img
# flow_from_directory: We use flow_from_directory when we are working with a directory of images

i = 0
# Run the loop till the number of images we wants
for batch in datagen.flow(input_batch, batch_size=1, save_to_dir='AugImages'):
    # plt.figure(i)
    # imgplot = plt.imshow(image.array_to_img(batch[0]))
    i += 1
    if i == 10:
        break
